# %%
import report

# %%
size=10
size_=10000
beta=0.75
inst=[4,4,[2,2,2,2,2,2]]
pcvar=[]
import numpy as np
# mean=np.arange(1,ship_num+1)
mean=np.array([i for i in range(len(inst[2]))])
covl=[2 for i in range(len(inst[2]))]
# a=list(a)
# a=random.sample(a,ship_num)
# mean=np.sort(a)
cov=np.zeros((len(inst[2]),len(inst[2])))
for i in range(len(inst[2])):
    for j in range(len(inst[2])):
        if i==j:
            cov[i][i]=covl[1]
for i in range(len(inst[2])):
    for j in range(len(inst[2])):
        if i!=j:
            cov[i][j]=0

OC=[]
EPS=0.1
a=0
UB=1000
LB=0
UB_k=[]
zk=[]
aaa=[]

model=report.CuttingPlaneAlgorithm(len(inst[2]),inst[0],inst[1],inst[2],size,size_,0.75,mean,cov,OC,zk,aaa)
model.solve()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-09-30
# Set parameter LazyConstraints to value 1
# Set parameter TimeLimit to value 3660
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 108 rows, 228 columns and 866 nonzeros
# Model fingerprint: 0xdc259dca
# Variable types: 132 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# [[0 0 0 2]
#  [1 3 0 2]
#  [3 5 1 4]
#  [6 6 4 5]]
# Len_dic= 6
# 7 7
# Presolve removed 20 rows and 8 columns
# Presolve time: 0.02s
# Presolved: 88 rows, 220 columns, 630 nonzeros
# Variable types: 132 continuous, 88 integer (88 binary)
# [[0 0 0 5]
#  [1 1 0 5]
#  [2 3 4 6]
#  [2 3 4 6]]
# Len_dic= 8
# 5 9
#
# Root relaxation: objective 0.000000e+00, 87 iterations, 0.01 seconds (0.00 work units)
# [[0 1 0 0]
#  [2 1 0 2]
#  [5 4 3 6]
#  [5 4 3 6]]
# Len_dic= 8
# 0 9
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     0    0.00000    0   13    0.00000    0.00000  0.00%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1041
#
# Explored 1 nodes (213 simplex iterations) in 0.39 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
#
# User-callback calls 228, time in user-callback 0.27 sec

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.21.4
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email:
# License: BSD
# Location: c:\users\daiki\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages
# Requires:
# Required-by: matplotlib, pandas, scipy, seaborn
# Note: you may need to restart the kernel to use updated packages.

# %%
result
# Out:
# array([[2, 0, 0, 1],
#        [2, 0, 0, 1],
#        [6, 4, 3, 5],
#        [6, 4, 3, 5]])

# %%
boxplot(result)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 96 rows, 96 columns and 432 nonzeros
# Model fingerprint: 0x7653d5fb
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 0 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 96 rows, 88 columns, 400 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[1 0 0 1]
#  [3 0 0 4]
#  [3 2 2 4]
#  [5 5 6 6]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 160 rows, 96 columns and 624 nonzeros
# Model fingerprint: 0x14f73017
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 48 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 112 rows, 88 columns, 528 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: objective 0.000000e+00, 24 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (24 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0 3 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[3 1 0 0]
#  [3 1 2 0]
#  [6 4 5 0]
#  [6 4 5 2]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 208 rows, 96 columns and 768 nonzeros
# Model fingerprint: 0x80e74690
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 80 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 128 rows, 88 columns, 656 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: objective 0.000000e+00, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0 2 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 2 1 0]
#  [0 2 1 0]
#  [3 6 5 4]
#  [3 6 5 4]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 240 rows, 96 columns and 864 nonzeros
# Model fingerprint: 0x4c425b2c
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 72 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 168 rows, 88 columns, 920 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: cutoff, 102 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 0 0 1]
#  [2 2 0 1]
#  [5 3 4 6]
#  [5 3 4 6]]
# the objective function 2.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 256 rows, 96 columns and 912 nonzeros
# Model fingerprint: 0x4c9c2536
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 5.0000000
# Presolve removed 80 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 176 rows, 88 columns, 1008 nonzeros
# Variable types: 0 continuous, 88 integer (88 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: cutoff, 82 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         4.00000    4.00000  0.00%     -    0s
#
# Explored 1 nodes (82 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 2 0 0]
#  [1 2 0 1]
#  [5 3 4 6]
#  [5 3 4 6]]
# the objective function 4.0

# %%
hist(penalty_cvar)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 96 rows, 96 columns and 432 nonzeros
# Model fingerprint: 0x7653d5fb
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 0 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 96 rows, 88 columns, 400 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[1 0 0 1]
#  [3 0 0 4]
#  [3 2 2 4]
#  [5 5 6 6]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 160 rows, 96 columns and 624 nonzeros
# Model fingerprint: 0x14f73017
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 4.0000000
# Presolve removed 48 rows and 8 columns
# Presolve time: 0.00s
# Presolved: 112 rows, 88 columns, 528 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: objective 0.000000e+00, 24 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (24 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0 3 4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[3 1 0 0]
#  [3 1 2 0]
#  [6 4 5 0]
#  [6 4 5 2]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 208 rows, 96 columns and 768 nonzeros
# Model fingerprint: 0x80e74690
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 80 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 128 rows, 88 columns, 656 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: objective 0.000000e+00, 40 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (40 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0 2 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 2 1 0]
#  [0 2 1 0]
#  [3 6 5 4]
#  [3 6 5 4]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 240 rows, 96 columns and 864 nonzeros
# Model fingerprint: 0x4c425b2c
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 6.0000000
# Presolve removed 72 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 168 rows, 88 columns, 920 nonzeros
# Found heuristic solution: objective 2.0000000
# Variable types: 0 continuous, 88 integer (88 binary)
#
# Root relaxation: cutoff, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.00000    2.00000  0.00%     -    0s
#
# Explored 1 nodes (102 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 2 6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 0 0 1]
#  [2 2 0 1]
#  [5 3 4 6]
#  [5 3 4 6]]
# the objective function 2.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 256 rows, 96 columns and 912 nonzeros
# Model fingerprint: 0x4c9c2536
# Variable types: 0 continuous, 96 integer (96 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 5.0000000
# Presolve removed 80 rows and 8 columns
# Presolve time: 0.01s
# Presolved: 176 rows, 88 columns, 1008 nonzeros
# Variable types: 0 continuous, 88 integer (88 binary)
# Found heuristic solution: objective 4.0000000
#
# Root relaxation: cutoff, 82 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         4.00000    4.00000  0.00%     -    0s
#
# Explored 1 nodes (82 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4 5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# ====================================================
# [[0 2 0 0]
#  [1 2 0 1]
#  [5 3 4 6]
#  [5 3 4 6]]
# the objective function 4.0
# len= 2500

# %%
size=1000
size_=10000
beta=0.75
inst=[5,5,[2,2,2,2,2,2,2,2,2,2]]
pcvar=[]
import numpy as np
# mean=np.arange(1,ship_num+1)
mean=np.array([i for i in range(len(inst[2]))])
covl=[2 for i in range(len(inst[2]))]
# a=list(a)
# a=random.sample(a,ship_num)
# mean=np.sort(a)
cov=np.zeros((len(inst[2]),len(inst[2])))
for i in range(len(inst[2])):
    for j in range(len(inst[2])):
        if i==j:
            cov[i][i]=covl[1]
for i in range(len(inst[2])):
    for j in range(len(inst[2])):
        if i!=j:
            cov[i][j]=0

OC=[]
EPS=0.1
a=0
UB=1000
LB=0
UB_k=[]
zk=[]
aaa=[]

model=CuttingPlaneAlgorithm(len(inst[2]),inst[0],inst[1],inst[2],size,size_,0.75,mean,cov,OC,zk,aaa)
model.solve()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-09-30
# Set parameter LazyConstraints to value 1
# Set parameter TimeLimit to value 3660
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 257 rows, 21252 columns and 4124 nonzeros
# Model fingerprint: 0x92fc0d3b
# Variable types: 21002 continuous, 250 integer (250 binary)
# Coefficient statistics:
#   Matrix range     [4e-03, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+00]
# Presolve removed 40 rows and 20 columns
# Presolve time: 0.09s
# Presolved: 217 rows, 21232 columns, 3379 nonzeros
# Variable types: 21002 continuous, 230 integer (230 binary)
#
# Root relaxation: objective 0.000000e+00, 146 iterations, 0.02 seconds (0.00 work units)
# [[ 0  4  0  0  3]
#  [ 1  6  0  2  5]
#  [ 1  9  0  2  5]
#  [ 7  9  4  3  6]
#  [ 8 10 10  8  7]]
# Len_dic= 741
# 936 936
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   45          -    0.00000      -     -   54s
# [[ 2  0  2  0  0]
#  [ 4  1  5  0  0]
#  [ 4  1  5  7  3]
#  [ 6  9  6  7  3]
#  [10  9 10  8  8]]
# Len_dic= 741
# 184 936
# H    0     0                       4.9240000    0.00000   100%     -   83s
#      0     0    0.00000    0   45    4.92400    0.00000   100%     -   93s
# [[ 2  0  0  0  0]
#  [ 4  1  5  2  0]
#  [ 4  1  5  7  3]
#  [ 6  9  6  7  3]
#  [10  9 10  8  8]]
# Len_dic= 741
# 231 936
# H    0     0                       4.7920000    0.00000   100%     -  132s
#      0     2    0.00000    0   45    4.79200    0.00000   100%     -  149s
#      1     4    0.00000    1   38    4.79200    0.00000   100%  1525  218s
#      3     6    0.00000    2   39    4.79200    0.00000   100%  3577  249s
# [[ 2  0  0  0  0]
#  [ 2  5  3  1  0]
#  [ 4  5  3  1  4]
#  [ 8  6 10  9  7]
#  [ 8  6 10  9  7]]
# Len_dic= 747
# 393 943
#      7    10    0.00000    3   47    4.79200    0.00000   100%  2482  367s
# [[ 0  0  0  0  0]
#  [ 4  6  1  1  2]
#  [ 4  6  3  9  2]
#  [ 8  7  3  9  5]
#  [ 8  7 10 10  5]]
# Len_dic= 747
# 587 943
# H   11    11                       4.3360000    0.00000   100%  2368  566s
# [[ 0  0  0  3  0]
#  [ 1  4  2  3  0]
#  [ 1  4  2  5  7]
#  [ 5  6  8  7 10]
#  [ 9  6  9  8 10]]
# Len_dic= 748
# 237 944
#     13    11    0.13600    3   47    4.33600    0.00000   100%  3008  599s
#     15    15    0.00000    4   47    4.33600    0.00000   100%  2628  637s
#     19    19    0.00000    5   47    4.33600    0.00000   100%  2198  819s
# [[ 1  0  0  0  0]
#  [ 1  0  3  6  4]
#  [ 2  2  3  6  4]
#  [ 8  9  7 10  5]
#  [ 8  9  7 10  5]]
# Len_dic= 762
# 528 978
#     23    23    0.00000    6   57    4.33600    0.00000   100%  2713 1519s
#     27    28    0.03400    7   60    4.33600    0.00000   100%  2823 1698s
# [[ 0  2  0  1  0]
#  [ 4  6  0  1  0]
#  [ 4  6  3  9  2]
#  [ 8  7  3  9  5]
#  [ 8  7 10 10  5]]
# Len_dic= 762
# 560 978
# H   28    28                       3.8720000    0.00000   100%  2722 1738s
#     32    34    0.00000    7   59    3.87200    0.00000   100%  2535 1801s
#     38    38    0.02200    9   54    3.87200    0.00000   100%  2456 1893s
# [[ 0  0  3  0  0]
#  [ 3  1  6  0  2]
#  [ 4  1  6  4  2]
#  [ 5  9 10  7  8]
#  [ 5  9 10  7  8]]
# Len_dic= 766
# 613 986
# [[ 0  2  0  0  3]
#  [ 0  2  1  0  3]
#  [ 7  4  1  6  5]
#  [ 7  4  9  6  5]
#  [10  8  9 10  8]]
# Len_dic= 766
# 394 986
# H   41    38                       3.0400000    0.00000   100%  2364 1965s
#     42    43    0.00000    9   36    3.04000    0.00000   100%  2453 2112s
#     47    48    0.00000   10   38    3.04000    0.00000   100%  2615 2177s
#     52    52    0.00000   10   53    3.04000    0.00000   100%  2596 2278s
# [[ 3  2  0  0  0]
#  [ 3  2  1  0  0]
#  [ 7  4  1  6  5]
#  [ 7  4  9  6  5]
#  [10  8  9 10  8]]
# Len_dic= 766
# 296 986
# H   58    60                       2.5840000    0.00000   100%  2426 2525s
#     70    68    0.30600   12   36    2.58400    0.00000   100%  2653 2740s
#     78    74    0.00000   12   45    2.58400    0.00000   100%  2591 2929s
#     84    93    0.00000   13   49    2.58400    0.00000   100%  2658 3177s
# [[ 0  3  1  0  0]
#  [ 2  4  6  0  0]
#  [ 2  4  6  3  1]
#  [ 8  9 10  5  7]
#  [ 8  9 10  5  7]]
# Len_dic= 766
# 387 986
# H   91    93                       1.7680000    0.00000   100%  2751 3211s
# [[ 0  0  1  0  1]
#  [ 3  4  6  0  2]
#  [ 3  4  6  0  2]
#  [ 8  9 10  5  7]
#  [ 8  9 10  5  7]]
# Len_dic= 766
# 313 986
# H   95    93                       1.3760000    0.00000   100%  2665 3241s
#    103   108    0.00000   15   52    1.37600    0.00000   100%  2599 3435s
# [[ 0  1  1  0  0]
#  [ 3  4  6  0  2]
#  [ 3  4  6  0  2]
#  [ 8  9 10  5  7]
#  [ 8  9 10  5  7]]
# Len_dic= 766
# 116 986
# *  111   108              26       0.6400000    0.00000   100%  2635 3469s
#    122   111    0.00000   16   47    0.64000    0.00000   100%  2655 3676s
#
# Cutting planes:
#   Lazy constraints: 372625
#
# Explored 143 nodes (361024 simplex iterations) in 3676.95 seconds (2456.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 0.64 1.376 1.768 ... 4.924
#
# Time limit reached
# Best objective 6.400000000000e-01, best bound 0.000000000000e+00, gap 100.0000%
#
# User-callback calls 99576, time in user-callback 466.44 sec

# %%
boxplot(result)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 205 rows, 200 columns and 940 nonzeros
# Model fingerprint: 0xdc7990cf
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 0 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 205 rows, 190 columns, 900 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 2  1  6  5  0]
#  [ 2  1  6  5  0]
#  [ 4  3  8  7  0]
#  [ 4  3 10  7  0]
#  [ 8  9 10  9  0]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 365 rows, 200 columns and 1420 nonzeros
# Model fingerprint: 0xbedad61c
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 120 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 245 rows, 190 columns, 1220 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 1.0000000
#
# Root relaxation: objective 0.000000e+00, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 1 3 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 3  0  0  1  2]
#  [ 3  0  0  1  6]
#  [ 7  0  2  5  6]
#  [ 7  4  5  8  9]
#  [10  4 10  8  9]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 505 rows, 200 columns and 1840 nonzeros
# Model fingerprint: 0xe5ec51d3
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 210 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 295 rows, 190 columns, 1620 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 1.0000000
#
# Root relaxation: objective 0.000000e+00, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     0    0.00000    0   40    0.00000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (97 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 1 3 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  1  2  0]
#  [ 3  0  5  2  0]
#  [ 3  4  5  6  1]
#  [ 7  4  9  6  8]
#  [ 7 10  9 10  8]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 625 rows, 200 columns and 2200 nonzeros
# Model fingerprint: 0xc5ef1484
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 210 rows and 10 columns
# Presolve time: 0.02s
# Presolved: 415 rows, 190 columns, 2510 nonzeros
# Found heuristic solution: objective 7.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 5.0000000
#
# Root relaxation: objective 0.000000e+00, 121 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (121 simplex iterations) in 0.11 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 5 7 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  0  0  0]
#  [ 3  2  5  1  4]
#  [ 3  2  5  1  4]
#  [ 8  7 10  6  9]
#  [ 8  7 10  6  9]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 725 rows, 200 columns and 2500 nonzeros
# Model fingerprint: 0x2eba2b25
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 260 rows and 10 columns
# Presolve time: 0.07s
# Presolved: 465 rows, 190 columns, 3100 nonzeros
# Found heuristic solution: objective 7.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
#
# Root relaxation: objective 2.000000e+00, 251 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.0000000    2.00000  0.00%     -    0s
#
# Explored 1 nodes (251 simplex iterations) in 0.24 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2 7 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  0  0  0]
#  [ 3  5  2  4  1]
#  [ 3  5  2  4  1]
#  [ 9  6  8 10  7]
#  [ 9  6  8 10  7]]
# the objective function 2.0

# %%
hist(penalty_cvar)
# Out:
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 205 rows, 200 columns and 940 nonzeros
# Model fingerprint: 0xdc7990cf
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 0 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 205 rows, 190 columns, 900 nonzeros
# Found heuristic solution: objective 0.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 2  1  6  5  0]
#  [ 2  1  6  5  0]
#  [ 4  3  8  7  0]
#  [ 4  3 10  7  0]
#  [ 8  9 10  9  0]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 365 rows, 200 columns and 1420 nonzeros
# Model fingerprint: 0xbedad61c
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 120 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 245 rows, 190 columns, 1220 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 1.0000000
#
# Root relaxation: objective 0.000000e+00, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 1 3 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 3  0  0  1  2]
#  [ 3  0  0  1  6]
#  [ 7  0  2  5  6]
#  [ 7  4  5  8  9]
#  [10  4 10  8  9]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 505 rows, 200 columns and 1840 nonzeros
# Model fingerprint: 0xe5ec51d3
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 210 rows and 10 columns
# Presolve time: 0.02s
# Presolved: 295 rows, 190 columns, 1620 nonzeros
# Found heuristic solution: objective 3.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 1.0000000
#
# Root relaxation: objective 0.000000e+00, 97 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       0.0000000    0.00000  0.00%     -    0s
#      0     0    0.00000    0   40    0.00000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (97 simplex iterations) in 0.08 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 1 3 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  1  2  0]
#  [ 3  0  5  2  0]
#  [ 3  4  5  6  1]
#  [ 7  4  9  6  8]
#  [ 7 10  9 10  8]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 625 rows, 200 columns and 2200 nonzeros
# Model fingerprint: 0xc5ef1484
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 210 rows and 10 columns
# Presolve time: 0.02s
# Presolved: 415 rows, 190 columns, 2510 nonzeros
# Found heuristic solution: objective 7.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
# Found heuristic solution: objective 5.0000000
#
# Root relaxation: objective 0.000000e+00, 121 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       0.0000000    0.00000  0.00%     -    0s
#
# Explored 1 nodes (121 simplex iterations) in 0.10 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0 5 7 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  0  0  0]
#  [ 3  2  5  1  4]
#  [ 3  2  5  1  4]
#  [ 8  7 10  6  9]
#  [ 8  7 10  6  9]]
# the objective function 0.0
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 725 rows, 200 columns and 2500 nonzeros
# Model fingerprint: 0x2eba2b25
# Variable types: 0 continuous, 200 integer (200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+00]
# Found heuristic solution: objective 16.0000000
# Presolve removed 260 rows and 10 columns
# Presolve time: 0.04s
# Presolved: 465 rows, 190 columns, 3100 nonzeros
# Found heuristic solution: objective 7.0000000
# Variable types: 0 continuous, 190 integer (190 binary)
#
# Root relaxation: objective 2.000000e+00, 251 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       2.0000000    2.00000  0.00%     -    0s
#
# Explored 1 nodes (251 simplex iterations) in 0.11 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 2 7 16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.000000000000e+00, best bound 2.000000000000e+00, gap 0.0000%
# ====================================================
# [[ 0  0  0  0  0]
#  [ 3  5  2  4  1]
#  [ 3  5  2  4  1]
#  [ 9  6  8 10  7]
#  [ 9  6  8 10  7]]
# the objective function 2.0
# len= 2500

# %%
print(result)
# Out:
# [[ 0  1  1  0  0]
#  [ 3  4  6  0  2]
#  [ 3  4  6  0  2]
#  [ 8  9 10  5  7]
#  [ 8  9 10  5  7]]
